# %%
import pandas as pd
import glob
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# %%
username = "postgres"
password = quote_plus("namrata@123")   # encode special characters
host = "localhost"
port = "5432"
database = "food_delivery_db"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# %%
parquet_files = glob.glob(r"C:/DE project/data/processed/data_lake/orders/*.parquet")  # adjust path

# Combine all Parquet files into a single DataFrame
df_list = [pd.read_parquet(file) for file in parquet_files]
df = pd.concat(df_list, ignore_index=True)

# %%
table_name = "orders"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'orders' in database 'food_delivery_db'.
